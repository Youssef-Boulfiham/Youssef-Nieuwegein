# %%
import pandas as pd
import numpy as np
# data = {
#     "ervaren gezondheid": [100],
#     "leeftijd": [50],
#     "geslacht": [1],
#     "roken": [0],
#     "alcohol": [1],
#     "softdrugs": [0],
#     "harddrugs": [0],
#     "thuis": [10],
#     "school": [5],
#     "vrienden": [2],
#     "vrije tijd": [1]
columns = ["ervaren gezondheid", "leeftijd", "geslacht", "roken", "alcohol", 
           "softdrugs", "harddrugs", "thuis", "school", "vrienden", "vrije tijd"]
data = np.random.randint(0, 1000001, size=(1, len(columns)))

df = pd.DataFrame(data, columns=columns)
df
df.to_csv('df_player.csv', sep=';', index=False)

# %%
from IPython.display import display, Image
display(Image("1.jpg"))
